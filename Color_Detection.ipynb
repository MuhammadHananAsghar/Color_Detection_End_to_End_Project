# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %matplotlib inline

# %%
image = cv2.imread('Coloured_Balls.png')
display_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
display_images = np.hstack([display_image,image, hsv])
plt.imshow(display_images)

# %%
# Blue Color Detection
lower_hue = np.array([109, 0, 0])
upper_hue = np.array([122, 255, 255])

mask = cv2.inRange(hsv, lower_hue, upper_hue)
result = cv2.bitwise_and(image, image, mask=mask)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result)

# %%
# Yellow Color Detection
lower_hue = np.array([21, 0, 0])
upper_hue = np.array([45, 255, 255])

mask = cv2.inRange(hsv, lower_hue, upper_hue)
result = cv2.bitwise_and(image, image, mask=mask)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result)

# %%
# Green Color Detection
lower_hue = np.array([50, 0, 0])
upper_hue = np.array([75, 255, 255])

mask = cv2.inRange(hsv, lower_hue, upper_hue)
result = cv2.bitwise_and(image, image, mask=mask)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result)

# %%
# Purple Color Detection
lower_hue = np.array([130, 0, 0])
upper_hue = np.array([150, 255, 255])

mask = cv2.inRange(hsv, lower_hue, upper_hue)
result = cv2.bitwise_and(image, image, mask=mask)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result)

# %%
# Orange Color Detection
lower_hue = np.array([1, 0, 0])
upper_hue = np.array([20, 255, 255])

mask = cv2.inRange(hsv, lower_hue, upper_hue)
result = cv2.bitwise_and(image, image, mask=mask)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result)

# %%
# Red Color Detection
lower_hue = np.array([170, 0, 0])
upper_hue = np.array([179, 255, 255])

mask = cv2.inRange(hsv, lower_hue, upper_hue)
result = cv2.bitwise_and(image, image, mask=mask)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result)

# %% [markdown]
# <strong style='color:cyan;'>Second Image(More Colors)</strong>

# %%
image = cv2.imread('second.jpg')
display_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

display_images = np.hstack([display_image,image, hsv])
plt.imshow(display_images)

# %%
# Pink Color Detection
lower_hue = np.array([142, 0, 0])
upper_hue = np.array([165, 255, 255])

mask = cv2.inRange(hsv, lower_hue, upper_hue)
result = cv2.bitwise_and(image, image, mask=mask)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result)

# %%
# Brown Color Detection
lower_hue = np.array([1, 0, 0])
upper_hue = np.array([32, 83, 83])

mask = cv2.inRange(hsv, lower_hue, upper_hue)
result = cv2.bitwise_and(image, image, mask=mask)
result = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
plt.imshow(result)

# %%
# Detected Colors

# 1. Brown
# 2. Pink
# 3. Yellow
# 4. Red
# 5. Orange
# 6. Green
# 7. Blue
# 8. Purple
